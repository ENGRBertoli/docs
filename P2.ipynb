# %% [markdown]
# <a href="https://colab.research.google.com/github/ENGRBertoli/docs/blob/main/P2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
balancas = []  # Lista para armazenar as balanças

while True:
    print("\nMenu de Gestão de Fabricação de Balanças")
    print("1. Adicionar Balança")
    print("2. Listar Balanças")
    print("3. Atualizar Status da Balança")
    print("4. Atualizar Estoque de Balança")
    print("5. Sair")
    escolha = input("Escolha uma opção: ")

    if escolha == '1':
        modelo = input("Modelo da balança: ")
        quantidade = int(input("Quantidade: "))
        status = "Em produção"
        nova_balanca = {
            "modelo": modelo,
            "quantidade": quantidade,
            "status": status
        }
        balancas.append(nova_balanca)  # Adiciona a nova balança à lista
        print(f"Balança '{modelo}' adicionada com quantidade {quantidade}.")

    elif escolha == '2':
        if not balancas:
            print("Nenhuma balança cadastrada.")  # Mensagem se a lista estiver vazia
        else:
            print("Balanças fabricadas:")
            for balanca in balancas:
                # Exibe as informações de cada balança
                print(f"Modelo: {balanca['modelo']}, Quantidade: {balanca['quantidade']}, Status: {balanca['status']}")

    elif escolha == '3':
        modelo = input("Modelo da balança a ser atualizado: ")
        novo_status = input("Novo status: ")
        encontrado = False
        for balanca in balancas:
            if balanca['modelo'] == modelo:
                balanca['status'] = novo_status  # Atualiza o status da balança encontrada
                print(f"Status da balança '{modelo}' atualizado para '{novo_status}'.")
                encontrado = True
                break
        if not encontrado:
            print(f"Balança '{modelo}' não encontrada.")  # Mensagem se a balança não for encontrada

    elif escolha == '4':
        modelo = input("Modelo da balança para atualizar o estoque: ")
        quantidade = int(input("Quantidade a ser adicionada ou subtraída (use negativo para subtrair): "))
        encontrado = False
        for balanca in balancas:
            if balanca['modelo'] == modelo:
                balanca['quantidade'] += quantidade  # Atualiza a quantidade
                if balanca['quantidade'] < 0:
                    balanca['quantidade'] = 0  # Não permite quantidade negativa
                print(f"Quantidade da balança '{modelo}' atualizada para {balanca['quantidade']}.")
                encontrado = True
                break
        if not encontrado:
            print(f"Balança '{modelo}' não encontrada.")  # Mensagem se a balança não for encontrada

    elif escolha == '5':
        print("Saindo do programa...")  # Mensagem de saída
        break

    else:
        print("Opção inválida. Tente novamente.")  # Mensagem para entrada inválida
# Out:
# Menu de Gestão de Fabricação de Balanças
# 1. Adicionar Balança
# 2. Listar Balanças
# 3. Atualizar Status da Balança
# 4. Atualizar Estoque de Balança
# 5. Sair
# Escolha uma opção: 1
# Modelo da balança: SP-6000
# Quantidade: 5
# Balança 'SP-6000' adicionada com quantidade 5.
#
# Menu de Gestão de Fabricação de Balanças
# 1. Adicionar Balança
# 2. Listar Balanças
# 3. Atualizar Status da Balança
# 4. Atualizar Estoque de Balança
# 5. Sair
# Escolha uma opção: 3
# Modelo da balança a ser atualizado: SP-6000
# Novo status: vendido
# Status da balança 'SP-6000' atualizado para 'vendido'.
#
# Menu de Gestão de Fabricação de Balanças
# 1. Adicionar Balança
# 2. Listar Balanças
# 3. Atualizar Status da Balança
# 4. Atualizar Estoque de Balança
# 5. Sair
# Escolha uma opção: 2
# Balanças fabricadas:
# Modelo: SP-6000, Quantidade: 5, Status: vendido
#
# Menu de Gestão de Fabricação de Balanças
# 1. Adicionar Balança
# 2. Listar Balanças
# 3. Atualizar Status da Balança
# 4. Atualizar Estoque de Balança
# 5. Sair
# Escolha uma opção: 4
# Modelo da balança para atualizar o estoque: SP-6000
# Quantidade a ser adicionada ou subtraída (use negativo para subtrair): -2
# Quantidade da balança 'SP-6000' atualizada para 3.
#
# Menu de Gestão de Fabricação de Balanças
# 1. Adicionar Balança
# 2. Listar Balanças
# 3. Atualizar Status da Balança
# 4. Atualizar Estoque de Balança
# 5. Sair
# Escolha uma opção: 2
# Balanças fabricadas:
# Modelo: SP-6000, Quantidade: 3, Status: vendido
#
# Menu de Gestão de Fabricação de Balanças
# 1. Adicionar Balança
# 2. Listar Balanças
# 3. Atualizar Status da Balança
# 4. Atualizar Estoque de Balança
# 5. Sair
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-3f3ff39d3ddf> in <cell line: 3>()
#       8     print("4. Atualizar Estoque de Balança")
#       9     print("5. Sair")
# ---> 10     escolha = input("Escolha uma opção: ")
#      11
#      12     if escolha == '1':
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
